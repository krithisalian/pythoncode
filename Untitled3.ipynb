# %%
import matplotlib.pyplot as plt
X=[1,2,3]
Y=[2,4,1]
plt.plot(X,Y)
plt.xlable('X-axis')
plt.ylable('Y-axis')
plt.title('My first graph')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       3 Y=[2,4,1]
#       4 plt.plot(X,Y)
# ----> 5 plt.xlable('X-axis')
#       6 plt.ylable('Y-axis')
#       7 plt.title('My first graph')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'
